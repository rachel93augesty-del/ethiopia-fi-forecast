# %% [markdown]
# Task 2: Exploratory Data Analysis – Ethiopia Financial Inclusion
#
# Objective: Analyze patterns and factors influencing financial inclusion.
# Scope: Dataset overview, access trends, usage (digital payments), infrastructure, event timeline, and correlation analysis.
# Deliverables: EDA notebook with visualizations, data quality assessment, and summary of key insights.
